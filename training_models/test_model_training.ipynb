# %% [markdown]
# ### Подключение к базе и таблицы с юзерами и постами

# %%
from dotenv import load_dotenv
from sqlalchemy.engine import URL
import os
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
load_dotenv()
# Out:
# True

# %%
connection = os.environ.get("POSG_ENG")

# %%
### Посты и топики
### С постами придется повозиться, сгенерируем эмбеддинги постов с помощью моделей transformers
import pandas as pd


posts_info = pd.read_sql(
    """SELECT * FROM public.post_text_df""",
    con=connection
)

posts_info
# Out:
#       post_id                                               text     topic
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 3 columns]

# %%
from transformers import AutoTokenizer
from transformers import BertModel
from transformers import RobertaModel
from transformers import DistilBertModel

# Функция для возврата предобученной модели и токенизатора

def get_model(model_name):
    # Проверяем, есть ли модель в наличии
    assert model_name in ['bert', 'roberta', 'distilbert']

    checkpoint_names = {
        'bert': 'bert-base-cased',
        'roberta': 'roberta-base',
        'distilbert': 'distilbert-base-cased'
    }

    model_classes = {
        'bert': BertModel,
        'roberta': RobertaModel,
        'distilbert': DistilBertModel
    }

    return AutoTokenizer.from_pretrained(checkpoint_names[model_name]), model_classes[model_name].from_pretrained(checkpoint_names[model_name])

# %%
tokenizer, model = get_model('distilbert')
# Out:
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertModel: ['vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
### Сделаем датасет для постов

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from transformers import DataCollatorWithPadding


class PostDataset(Dataset):
    def __init__(self, texts, tokenizer):
        super().__init__()

        self.texts = tokenizer.batch_encode_plus(
            texts,
            add_special_tokens=True,
            return_token_type_ids=False,
            return_tensors='pt',
            truncation=True,
            padding=True
        )
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        return {'input_ids': self.texts['input_ids'][idx], 'attention_mask': self.texts['attention_mask'][idx]}

    def __len__(self):
        return len(self.texts['input_ids'])
    
    
dataset = PostDataset(posts_info['text'].values.tolist(), tokenizer)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

loader = DataLoader(dataset, batch_size=32, collate_fn=data_collator, pin_memory=True, shuffle=False)

# %%
import torch
from tqdm import tqdm


@torch.inference_mode()
def get_embeddings_labels(model, loader):
    model.eval()
    
    total_embeddings = []
    
    for batch in tqdm(loader):
        batch = {key: batch[key].to(device) for key in ['attention_mask', 'input_ids']}

        embeddings = model(**batch)['last_hidden_state'][:, 0, :]

        total_embeddings.append(embeddings.cpu())

    return torch.cat(total_embeddings, dim=0)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

print(device)
print(torch.cuda.get_device_name())

model = model.to(device)
# Out:
# cuda:0
# NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
embeddings = get_embeddings_labels(model, loader).numpy()

embeddings
# Out:
#   0%|                                                                                          | 0/220 [00:00<?, ?it/s]You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# 100%|████████████████████████████████████████████████████████████████████████████████| 220/220 [01:52<00:00,  1.96it/s]
# array([[ 3.63150865e-01,  4.89376076e-02, -2.64081180e-01, ...,
#         -1.41593322e-01,  1.59181338e-02,  9.17690195e-05],
#        [ 2.36416355e-01, -1.59500718e-01, -3.27798098e-01, ...,
#         -2.89936095e-01,  1.19365320e-01, -1.62343075e-03],
#        [ 3.75191331e-01, -1.13944076e-01, -2.40547031e-01, ...,
#         -3.38919759e-01,  5.86940572e-02, -2.12656837e-02],
#        ...,
#        [ 3.40382695e-01,  6.64923638e-02, -1.63184494e-01, ...,
#         -8.65628794e-02,  2.03403875e-01,  3.20906416e-02],
#        [ 4.32091892e-01,  1.10916262e-02, -1.17306069e-01, ...,
#          7.54015967e-02,  1.02739766e-01,  1.52742090e-02],
#        [ 3.04277748e-01, -7.62156770e-02, -6.77585602e-02, ...,
#         -5.43488115e-02,  2.44383752e-01, -1.41487354e-02]], dtype=float32)

# %%
### Кластеризуем тексты

from sklearn.decomposition import PCA

centered = embeddings - embeddings.mean()

pca = PCA(n_components=50)
pca_decomp = pca.fit_transform(centered)

# %%
from sklearn.cluster import KMeans

n_clusters = 15

kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(pca_decomp)

posts_info['TextCluster'] = kmeans.labels_

dists_columns = [f'DistanceToCluster_{i}' for i in range(n_clusters)]

dists_df = pd.DataFrame(
    data=kmeans.transform(pca_decomp),
    columns=dists_columns
)

dists_df.head()
# Out:
#    DistanceToCluster_0  DistanceToCluster_1  DistanceToCluster_2  \
# 0             3.372981             3.449238             3.613279
# 1             3.327286             3.129955             3.375149
# 2             3.263707             3.136165             3.334628
# 3             3.517888             3.770270             3.167191
# 4             3.031014             2.830061             3.065462
#
#    DistanceToCluster_3  DistanceToCluster_4  DistanceToCluster_5  \
# 0             2.455638             1.475142             3.410075
# 1             2.374099             2.187458             3.291418
# 2             2.418176             2.277349             3.308573
# 3             2.842223             2.716161             3.736576
# 4             2.014575             2.055249             2.789516
#
#    DistanceToCluster_6  DistanceToCluster_7  DistanceToCluster_8  \
# 0             3.401131             3.605847             3.482929
# 1             3.440351             3.347250             3.258184
# 2             3.549620             3.340957             3.403425
# 3             3.747341             3.791014             4.074710
# 4             2.850697             3.022428             3.245411
#
#    DistanceToCluster_9  DistanceToCluster_10  DistanceToCluster_11  \
# 0             1.889863              2.990790              3.417781
# 1             1.672582              2.841858              3.274209
# 2             1.582005              3.051923              3.366638
# 3             2.356338              3.256052              3.790800
# 4             1.733670              2.643581              2.753824
#
#    DistanceToCluster_12  DistanceToCluster_13  DistanceToCluster_14
# 0              2.330397              3.443002              2.839993
# 1              2.251417              2.983633              2.548337
# 2              3.114794              2.971580              2.866056
# 3              3.462207              3.721126              3.368291
# 4              3.005219              2.636937              2.116556

# %%
# Из таблицы постов для контрольной модели заберем столбец TotalTfIdf

post_df = pd.read_sql('SELECT * FROM a_maslennikov_post_features_lesson_22', con=connection)
post_df
# Out:
#       post_id     topic  count_words  first_sent_Tsne_1st_component  \
# 0           1  business          318                      -0.038906
# 1           2  business          441                      -0.193684
# 2           3  business          538                      -2.080238
# 3           4  business          170                      -1.724925
# 4           5  business          147                      -3.208512
# ...       ...       ...          ...                            ...
# 7018     7315     movie          158                       1.374488
# 7019     7316     movie          149                      -0.589877
# 7020     7317     movie          110                       0.057531
# 7021     7318     movie          139                      -0.113747
# 7022     7319     movie          124                       0.991706
#
#       first_sent_Tsne_2nd_component  stop_Tsne_1st_component  \
# 0                         -2.144652                42.836586
# 1                         -0.233893                52.825260
# 2                          0.541324                49.007130
# 3                         -0.322325                59.282013
# 4                          0.380261                66.092705
# ...                             ...                      ...
# 7018                      -1.621203               -28.808765
# 7019                      -0.506263               -42.102474
# 7020                      -0.210220               -14.665745
# 7021                      -0.901559               -19.301165
# 7022                       0.121799                -6.277150
#
#       stop_Tsne_2nd_component  tf_idf_stop_max  tf_idf_stop_mean  TotalTfIdf  \
# 0                  -37.384290         0.462776          0.000495    8.748129
# 1                  -14.826131         0.452829          0.004566   11.878472
# 2                  -25.862959         0.064370          0.000009   12.675530
# 3                  -26.647335         0.104535          0.000015    6.622786
# 4                  -35.834000         0.324894          0.000385    6.352096
# ...                       ...              ...               ...         ...
# 7018                11.856544         0.158955          0.000110   10.326422
# 7019                -8.204050         0.063389          0.000009    6.703302
# 7020                28.933609         0.161935          0.000023    6.471377
# 7021                46.332840         0.296780          0.000262    5.628524
# 7022                 3.654688         0.210809          0.000053    6.883375
#
#       ...  DistanceTo9thCluster  DistanceTo10thCluster  DistanceTo11thCluster  \
# 0     ...              0.438651               0.260549               0.423094
# 1     ...              0.296305               0.228026               0.189926
# 2     ...              0.320943               0.094624               0.298398
# 3     ...              0.262113               0.120913               0.220605
# 4     ...              0.223714               0.178550               0.177725
# ...   ...                   ...                    ...                    ...
# 7018  ...              0.497821               0.500031               0.477741
# 7019  ...              0.388586               0.389387               0.358348
# 7020  ...              0.335177               0.335056               0.319898
# 7021  ...              0.316369               0.313044               0.290388
# 7022  ...              0.338778               0.330362               0.298833
#
#       DistanceTo12thCluster  DistanceTo13thCluster  DistanceTo14thCluster  \
# 0                  0.455818               0.545878               0.529774
# 1                  0.340904               0.458724               0.428792
# 2                  0.338253               0.478707               0.433204
# 3                  0.301639               0.440330               0.385237
# 4                  0.234821               0.399142               0.343519
# ...                     ...                    ...                    ...
# 7018               0.481328               0.575820               0.563288
# 7019               0.366467               0.488602               0.447671
# 7020               0.334323               0.434197               0.410456
# 7021               0.306138               0.397719               0.377855
# 7022               0.318585               0.364141               0.412172
#
#       DistanceTo15thCluster  embedding_1  embedding_2  embedding_3
# 0                  0.498790    -0.782232    -2.211454    -0.206105
# 1                  0.395859    -0.670262    -1.993636    -0.072089
# 2                  0.396169    -0.641463    -1.735066    -0.448774
# 3                  0.321376    -0.321566    -1.744855    -0.555411
# 4                  0.295413    -0.645753    -1.341985    -0.605482
# ...                     ...          ...          ...          ...
# 7018               0.540482    -1.192416     1.312018     0.698750
# 7019               0.428157    -0.999023     1.237880     0.928317
# 7020               0.382911    -0.732479     1.445922     0.655112
# 7021               0.344800    -1.589979     1.253510    -0.387252
# 7022               0.382005    -0.603847     0.714141    -0.913411
#
# [7023 rows x 31 columns]

# %%
posts_info = pd.concat(([posts_info, dists_df, post_df.TotalTfIdf]), axis=1)

# posts_info.drop(["text"], axis=1, inplace=True)

posts_info
# Out:
#       post_id                                               text     topic  \
# 0           1  UK economy facing major risks\n\nThe UK manufa...  business
# 1           2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2           3  Asian quake hits European shares\n\nShares in ...  business
# 3           4  India power shares jump on debut\n\nShares in ...  business
# 4           5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...       ...                                                ...       ...
# 7018     7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019     7316  I give this movie 2 stars purely because of it...     movie
# 7020     7317  I cant believe this film was allowed to be mad...     movie
# 7021     7318  The version I saw of this film was the Blockbu...     movie
# 7022     7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
#       TextCluster  DistanceToCluster_0  DistanceToCluster_1  \
# 0               4             3.372981             3.449238
# 1               9             3.327286             3.129955
# 2               9             3.263707             3.136165
# 3               9             3.517888             3.770270
# 4               9             3.031014             2.830061
# ...           ...                  ...                  ...
# 7018            5             3.133314             1.883501
# 7019            5             2.930391             1.788261
# 7020            5             2.833125             2.049317
# 7021           11             3.430785             1.730188
# 7022            1             3.296419             1.797207
#
#       DistanceToCluster_2  DistanceToCluster_3  DistanceToCluster_4  \
# 0                3.613279             2.455638             1.475142
# 1                3.375149             2.374099             2.187458
# 2                3.334628             2.418176             2.277349
# 3                3.167191             2.842223             2.716161
# 4                3.065462             2.014575             2.055249
# ...                   ...                  ...                  ...
# 7018             2.063278             2.706920             3.132088
# 7019             1.889994             2.420229             2.926131
# 7020             2.291133             2.788901             3.211434
# 7021             1.742197             2.960285             3.268011
# 7022             2.074504             2.857620             3.426815
#
#       DistanceToCluster_5  DistanceToCluster_6  DistanceToCluster_7  \
# 0                3.410075             3.401131             3.605847
# 1                3.291418             3.440351             3.347250
# 2                3.308573             3.549620             3.340957
# 3                3.736576             3.747341             3.791014
# 4                2.789516             2.850697             3.022428
# ...                   ...                  ...                  ...
# 7018             1.244245             1.729265             2.939593
# 7019             0.979706             1.182690             2.589023
# 7020             1.417765             1.973036             2.373447
# 7021             1.571262             1.184330             3.292385
# 7022             2.152666             2.143019             3.024686
#
#       DistanceToCluster_8  DistanceToCluster_9  DistanceToCluster_10  \
# 0                3.482929             1.889863              2.990790
# 1                3.258184             1.672582              2.841858
# 2                3.403425             1.582005              3.051923
# 3                4.074710             2.356338              3.256052
# 4                3.245411             1.733670              2.643581
# ...                   ...                  ...                   ...
# 7018             3.400325             2.921895              2.820483
# 7019             3.389828             2.943105              2.508392
# 7020             3.468269             3.166540              2.539971
# 7021             3.414608             3.187736              3.109109
# 7022             3.611301             3.191249              2.985365
#
#       DistanceToCluster_11  DistanceToCluster_12  DistanceToCluster_13  \
# 0                 3.417781              2.330397              3.443002
# 1                 3.274209              2.251417              2.983633
# 2                 3.366638              3.114794              2.971580
# 3                 3.790800              3.462207              3.721126
# 4                 2.753824              3.005219              2.636937
# ...                    ...                   ...                   ...
# 7018              1.799387              3.392599              3.053521
# 7019              1.742759              3.240019              3.199836
# 7020              2.006334              3.446405              3.158383
# 7021              1.137585              3.477916              3.218224
# 7022              1.968157              3.596280              3.247817
#
#       DistanceToCluster_14  TotalTfIdf
# 0                 2.839993    8.748129
# 1                 2.548337   11.878472
# 2                 2.866056   12.675530
# 3                 3.368291    6.622786
# 4                 2.116556    6.352096
# ...                    ...         ...
# 7018              2.304960   10.326422
# 7019              2.218261    6.703302
# 7020              2.429204    6.471377
# 7021              2.272495    5.628524
# 7022              2.644236    6.883375
#
# [7023 rows x 20 columns]

# %%
### Очищаем память

model.cpu()

del model
del tokenizer

del dataset
del loader

del embeddings
del centered
del pca
del pca_decomp
del post_df

# %%
import gc

gc.collect()
# Out:
# 116

# %%
# posts_info.to_sql("a_maslennikov_post_features_lesson_4_22", con=connection, if_exists='replace')

# %%
posts_info.drop(["text"], axis=1, inplace=True)
posts_info
# Out:
#       post_id     topic  TextCluster  DistanceToCluster_0  \
# 0           1  business            4             3.372981
# 1           2  business            9             3.327286
# 2           3  business            9             3.263707
# 3           4  business            9             3.517888
# 4           5  business            9             3.031014
# ...       ...       ...          ...                  ...
# 7018     7315     movie            5             3.133314
# 7019     7316     movie            5             2.930391
# 7020     7317     movie            5             2.833125
# 7021     7318     movie           11             3.430785
# 7022     7319     movie            1             3.296419
#
#       DistanceToCluster_1  DistanceToCluster_2  DistanceToCluster_3  \
# 0                3.449238             3.613279             2.455638
# 1                3.129955             3.375149             2.374099
# 2                3.136165             3.334628             2.418176
# 3                3.770270             3.167191             2.842223
# 4                2.830061             3.065462             2.014575
# ...                   ...                  ...                  ...
# 7018             1.883501             2.063278             2.706920
# 7019             1.788261             1.889994             2.420229
# 7020             2.049317             2.291133             2.788901
# 7021             1.730188             1.742197             2.960285
# 7022             1.797207             2.074504             2.857620
#
#       DistanceToCluster_4  DistanceToCluster_5  DistanceToCluster_6  \
# 0                1.475142             3.410075             3.401131
# 1                2.187458             3.291418             3.440351
# 2                2.277349             3.308573             3.549620
# 3                2.716161             3.736576             3.747341
# 4                2.055249             2.789516             2.850697
# ...                   ...                  ...                  ...
# 7018             3.132088             1.244245             1.729265
# 7019             2.926131             0.979706             1.182690
# 7020             3.211434             1.417765             1.973036
# 7021             3.268011             1.571262             1.184330
# 7022             3.426815             2.152666             2.143019
#
#       DistanceToCluster_7  DistanceToCluster_8  DistanceToCluster_9  \
# 0                3.605847             3.482929             1.889863
# 1                3.347250             3.258184             1.672582
# 2                3.340957             3.403425             1.582005
# 3                3.791014             4.074710             2.356338
# 4                3.022428             3.245411             1.733670
# ...                   ...                  ...                  ...
# 7018             2.939593             3.400325             2.921895
# 7019             2.589023             3.389828             2.943105
# 7020             2.373447             3.468269             3.166540
# 7021             3.292385             3.414608             3.187736
# 7022             3.024686             3.611301             3.191249
#
#       DistanceToCluster_10  DistanceToCluster_11  DistanceToCluster_12  \
# 0                 2.990790              3.417781              2.330397
# 1                 2.841858              3.274209              2.251417
# 2                 3.051923              3.366638              3.114794
# 3                 3.256052              3.790800              3.462207
# 4                 2.643581              2.753824              3.005219
# ...                    ...                   ...                   ...
# 7018              2.820483              1.799387              3.392599
# 7019              2.508392              1.742759              3.240019
# 7020              2.539971              2.006334              3.446405
# 7021              3.109109              1.137585              3.477916
# 7022              2.985365              1.968157              3.596280
#
#       DistanceToCluster_13  DistanceToCluster_14  TotalTfIdf
# 0                 3.443002              2.839993    8.748129
# 1                 2.983633              2.548337   11.878472
# 2                 2.971580              2.866056   12.675530
# 3                 3.721126              3.368291    6.622786
# 4                 2.636937              2.116556    6.352096
# ...                    ...                   ...         ...
# 7018              3.053521              2.304960   10.326422
# 7019              3.199836              2.218261    6.703302
# 7020              3.158383              2.429204    6.471377
# 7021              3.218224              2.272495    5.628524
# 7022              3.247817              2.644236    6.883375
#
# [7023 rows x 19 columns]

# %% [markdown]
# ## Теперь приступаем к обработке действий

# %%
### Заберем 10 млн, сразу очистим и оставим только view


feed_data = pd.read_sql(
    """
    SELECT
        cast(extract(hour from timestamp) as int) as hour,
        cast(extract(month from timestamp) as int) as month,
        post_id,
        gender,
        age,
        country,
        city,
        exp_group,
        os,
        source,
        target
    FROM public.feed_data JOIN public.user_data ON public.feed_data.user_id = public.user_data.user_id
    WHERE action = 'view'
    LIMIT 10000000
    """,
    con=connection
)

feed_data.head()
# Out:
#    hour  month  post_id  gender  age country        city  exp_group   os  \
# 0    13     10      983       1   18  Russia  Domodedovo          2  iOS
# 1    14     10     3475       1   18  Russia  Domodedovo          2  iOS
# 2    14     10     3886       1   18  Russia  Domodedovo          2  iOS
# 3    14     10     5379       1   18  Russia  Domodedovo          2  iOS
# 4    14     10     1365       1   18  Russia  Domodedovo          2  iOS
#
#   source  target
# 0    ads       0
# 1    ads       0
# 2    ads       0
# 3    ads       0
# 4    ads       0

# %%
from catboost import CatBoostClassifier

object_cols = [
    'topic', 'TextCluster', 'gender', 'country',
    'city', 'exp_group', 'hour', 'month',
    'os', 'source'
]

catboost = CatBoostClassifier(
    iterations=200,
    learning_rate=1,
    depth=2,
    random_seed=12345612,
    thread_count=-1,
    task_type="GPU"
)

feed_data = pd.merge(
    feed_data,
    posts_info,
    on='post_id',
    how='left'
)

del posts_info

feed_data.drop(['post_id'], axis=1, inplace=True)

catboost.fit(X=feed_data.drop(['target'], axis=1), y=feed_data['target'], cat_features=object_cols)

catboost.save_model(
    'catboost_model',
    format="cbm"                  
)
# Out:
# Warning: less than 75% gpu memory available for training. Free: 1812.450001 Total: 4095.5
# 0:	learn: 0.3630571	total: 283ms	remaining: 56.3s
# 1:	learn: 0.3550332	total: 539ms	remaining: 53.4s
# 2:	learn: 0.3535784	total: 774ms	remaining: 50.8s
# 3:	learn: 0.3529531	total: 1.03s	remaining: 50.5s
# 4:	learn: 0.3527287	total: 1.24s	remaining: 48.3s
# 5:	learn: 0.3516139	total: 1.47s	remaining: 47.7s
# 6:	learn: 0.3507214	total: 1.68s	remaining: 46.4s
# 7:	learn: 0.3506147	total: 1.9s	remaining: 45.5s
# 8:	learn: 0.3504213	total: 2.12s	remaining: 44.9s
# 9:	learn: 0.3503276	total: 2.34s	remaining: 44.5s
# 10:	learn: 0.3500488	total: 2.54s	remaining: 43.7s
# 11:	learn: 0.3499600	total: 2.75s	remaining: 43s
# 12:	learn: 0.3494120	total: 2.95s	remaining: 42.5s
# 13:	learn: 0.3492238	total: 3.16s	remaining: 42s
# 14:	learn: 0.3489585	total: 3.37s	remaining: 41.5s
# 15:	learn: 0.3487837	total: 3.61s	remaining: 41.5s
# 16:	learn: 0.3487505	total: 3.84s	remaining: 41.3s
# 17:	learn: 0.3481510	total: 4.04s	remaining: 40.9s
# 18:	learn: 0.3480733	total: 4.25s	remaining: 40.5s
# 19:	learn: 0.3480354	total: 4.48s	remaining: 40.3s
# 20:	learn: 0.3478560	total: 4.69s	remaining: 40s
# 21:	learn: 0.3478051	total: 4.95s	remaining: 40s
# 22:	learn: 0.3477623	total: 5.15s	remaining: 39.6s
# 23:	learn: 0.3475608	total: 5.34s	remaining: 39.2s
# 24:	learn: 0.3474751	total: 5.66s	remaining: 39.6s
# 25:	learn: 0.3474445	total: 5.94s	remaining: 39.7s
# 26:	learn: 0.3474223	total: 6.22s	remaining: 39.9s
# 27:	learn: 0.3474018	total: 6.43s	remaining: 39.5s
# 28:	learn: 0.3473864	total: 6.63s	remaining: 39.1s
# 29:	learn: 0.3473483	total: 6.84s	remaining: 38.7s
# 30:	learn: 0.3472758	total: 7.04s	remaining: 38.4s
# 31:	learn: 0.3472024	total: 7.24s	remaining: 38s
# 32:	learn: 0.3471676	total: 7.45s	remaining: 37.7s
# 33:	learn: 0.3471405	total: 7.65s	remaining: 37.3s
# 34:	learn: 0.3471226	total: 7.86s	remaining: 37s
# 35:	learn: 0.3470569	total: 8.06s	remaining: 36.7s
# 36:	learn: 0.3470395	total: 8.28s	remaining: 36.5s
# 37:	learn: 0.3470296	total: 8.48s	remaining: 36.2s
# 38:	learn: 0.3470209	total: 8.68s	remaining: 35.8s
# 39:	learn: 0.3469804	total: 8.87s	remaining: 35.5s
# 40:	learn: 0.3469724	total: 9.07s	remaining: 35.2s
# 41:	learn: 0.3469548	total: 9.29s	remaining: 35s
# 42:	learn: 0.3469453	total: 9.49s	remaining: 34.7s
# 43:	learn: 0.3469095	total: 9.81s	remaining: 34.8s
# 44:	learn: 0.3468572	total: 10s	remaining: 34.5s
# 45:	learn: 0.3468289	total: 10.3s	remaining: 34.4s
# 46:	learn: 0.3468168	total: 10.5s	remaining: 34.1s
# 47:	learn: 0.3468040	total: 10.7s	remaining: 33.8s
# 48:	learn: 0.3467642	total: 10.9s	remaining: 33.5s
# 49:	learn: 0.3467351	total: 11.1s	remaining: 33.2s
# 50:	learn: 0.3467096	total: 11.3s	remaining: 32.9s
# 51:	learn: 0.3466932	total: 11.5s	remaining: 32.7s
# 52:	learn: 0.3466649	total: 11.7s	remaining: 32.4s
# 53:	learn: 0.3466533	total: 11.9s	remaining: 32.2s
# 54:	learn: 0.3466401	total: 12.1s	remaining: 31.9s
# 55:	learn: 0.3466236	total: 12.3s	remaining: 31.7s
# 56:	learn: 0.3465344	total: 12.5s	remaining: 31.5s
# 57:	learn: 0.3464713	total: 12.7s	remaining: 31.2s
# 58:	learn: 0.3464557	total: 12.9s	remaining: 30.9s
# 59:	learn: 0.3464420	total: 13.1s	remaining: 30.7s
# 60:	learn: 0.3464043	total: 13.3s	remaining: 30.4s
# 61:	learn: 0.3463817	total: 13.5s	remaining: 30.1s
# 62:	learn: 0.3463534	total: 13.7s	remaining: 29.8s
# 63:	learn: 0.3463405	total: 13.9s	remaining: 29.6s
# 64:	learn: 0.3463211	total: 14.1s	remaining: 29.3s
# 65:	learn: 0.3463089	total: 14.3s	remaining: 29.1s
# 66:	learn: 0.3462938	total: 14.6s	remaining: 29s
# 67:	learn: 0.3462839	total: 14.8s	remaining: 28.7s
# 68:	learn: 0.3462224	total: 15s	remaining: 28.4s
# 69:	learn: 0.3462130	total: 15.2s	remaining: 28.2s
# 70:	learn: 0.3462032	total: 15.4s	remaining: 27.9s
# 71:	learn: 0.3461945	total: 15.6s	remaining: 27.8s
# 72:	learn: 0.3461868	total: 15.8s	remaining: 27.5s
# 73:	learn: 0.3461823	total: 16s	remaining: 27.3s
# 74:	learn: 0.3461776	total: 16.2s	remaining: 27.1s
# 75:	learn: 0.3461242	total: 16.4s	remaining: 26.8s
# 76:	learn: 0.3461128	total: 16.7s	remaining: 26.6s
# 77:	learn: 0.3460803	total: 16.9s	remaining: 26.4s
# 78:	learn: 0.3460727	total: 17.1s	remaining: 26.1s
# 79:	learn: 0.3460571	total: 17.3s	remaining: 25.9s
# 80:	learn: 0.3460486	total: 17.5s	remaining: 25.7s
# 81:	learn: 0.3460421	total: 17.7s	remaining: 25.4s
# 82:	learn: 0.3460332	total: 17.9s	remaining: 25.2s
# 83:	learn: 0.3459521	total: 18.1s	remaining: 25s
# 84:	learn: 0.3459426	total: 18.3s	remaining: 24.7s
# 85:	learn: 0.3459345	total: 18.5s	remaining: 24.5s
# 86:	learn: 0.3459265	total: 18.7s	remaining: 24.3s
# 87:	learn: 0.3459149	total: 18.9s	remaining: 24s
# 88:	learn: 0.3458991	total: 19.2s	remaining: 23.9s
# 89:	learn: 0.3458070	total: 19.4s	remaining: 23.7s
# 90:	learn: 0.3457924	total: 19.6s	remaining: 23.5s
# 91:	learn: 0.3457822	total: 19.8s	remaining: 23.2s
# 92:	learn: 0.3457670	total: 20s	remaining: 23s
# 93:	learn: 0.3457524	total: 20.2s	remaining: 22.8s
# 94:	learn: 0.3457454	total: 20.4s	remaining: 22.5s
# 95:	learn: 0.3457250	total: 20.6s	remaining: 22.3s
# 96:	learn: 0.3457207	total: 20.8s	remaining: 22.1s
# 97:	learn: 0.3457112	total: 21.1s	remaining: 21.9s
# 98:	learn: 0.3456951	total: 21.3s	remaining: 21.8s
# 99:	learn: 0.3456921	total: 21.5s	remaining: 21.5s
# 100:	learn: 0.3456625	total: 21.7s	remaining: 21.3s
# 101:	learn: 0.3456570	total: 21.9s	remaining: 21.1s
# 102:	learn: 0.3456369	total: 22.1s	remaining: 20.8s
# 103:	learn: 0.3455898	total: 22.3s	remaining: 20.6s
# 104:	learn: 0.3455451	total: 22.5s	remaining: 20.4s
# 105:	learn: 0.3455427	total: 22.7s	remaining: 20.1s
# 106:	learn: 0.3455338	total: 22.9s	remaining: 19.9s
# 107:	learn: 0.3455253	total: 23.1s	remaining: 19.7s
# 108:	learn: 0.3455179	total: 23.3s	remaining: 19.5s
# 109:	learn: 0.3455054	total: 23.5s	remaining: 19.2s
# 110:	learn: 0.3454951	total: 23.7s	remaining: 19s
# 111:	learn: 0.3454624	total: 23.9s	remaining: 18.8s
# 112:	learn: 0.3454471	total: 24.1s	remaining: 18.6s
# 113:	learn: 0.3454320	total: 24.3s	remaining: 18.4s
# 114:	learn: 0.3454086	total: 24.6s	remaining: 18.1s
# 115:	learn: 0.3454026	total: 24.8s	remaining: 18s
# 116:	learn: 0.3453970	total: 25s	remaining: 17.8s
# 117:	learn: 0.3453908	total: 25.3s	remaining: 17.6s
# 118:	learn: 0.3453868	total: 25.5s	remaining: 17.3s
# 119:	learn: 0.3453804	total: 25.7s	remaining: 17.1s
# 120:	learn: 0.3453771	total: 25.9s	remaining: 16.9s
# 121:	learn: 0.3453736	total: 26.1s	remaining: 16.7s
# 122:	learn: 0.3453615	total: 26.3s	remaining: 16.4s
# 123:	learn: 0.3453542	total: 26.5s	remaining: 16.2s
# 124:	learn: 0.3453451	total: 26.7s	remaining: 16s
# 125:	learn: 0.3453453	total: 26.9s	remaining: 15.8s
# 126:	learn: 0.3453399	total: 27.1s	remaining: 15.6s
# 127:	learn: 0.3453353	total: 27.3s	remaining: 15.4s
# 128:	learn: 0.3453303	total: 27.5s	remaining: 15.1s
# 129:	learn: 0.3453238	total: 27.7s	remaining: 14.9s
# 130:	learn: 0.3453206	total: 28s	remaining: 14.7s
# 131:	learn: 0.3453158	total: 28.2s	remaining: 14.5s
# 132:	learn: 0.3453086	total: 28.4s	remaining: 14.3s
# 133:	learn: 0.3453047	total: 28.6s	remaining: 14.1s
# 134:	learn: 0.3452974	total: 28.8s	remaining: 13.9s
# 135:	learn: 0.3452881	total: 29s	remaining: 13.6s
# 136:	learn: 0.3452811	total: 29.2s	remaining: 13.4s
# 137:	learn: 0.3452735	total: 29.5s	remaining: 13.3s
# 138:	learn: 0.3452558	total: 29.8s	remaining: 13.1s
# 139:	learn: 0.3452508	total: 30s	remaining: 12.9s
# 140:	learn: 0.3452445	total: 30.2s	remaining: 12.6s
# 141:	learn: 0.3452403	total: 30.4s	remaining: 12.4s
# 142:	learn: 0.3452299	total: 30.7s	remaining: 12.2s
# 143:	learn: 0.3452208	total: 31s	remaining: 12.1s
# 144:	learn: 0.3452157	total: 31.2s	remaining: 11.8s
# 145:	learn: 0.3452141	total: 31.5s	remaining: 11.6s
# 146:	learn: 0.3452091	total: 31.7s	remaining: 11.4s
# 147:	learn: 0.3452044	total: 31.9s	remaining: 11.2s
# 148:	learn: 0.3452001	total: 32.1s	remaining: 11s
# 149:	learn: 0.3451960	total: 32.3s	remaining: 10.8s
# 150:	learn: 0.3451908	total: 32.5s	remaining: 10.5s
# 151:	learn: 0.3451850	total: 32.7s	remaining: 10.3s
# 152:	learn: 0.3451777	total: 32.9s	remaining: 10.1s
# 153:	learn: 0.3451694	total: 33.1s	remaining: 9.88s
# 154:	learn: 0.3451655	total: 33.3s	remaining: 9.66s
# 155:	learn: 0.3451624	total: 33.5s	remaining: 9.44s
# 156:	learn: 0.3451563	total: 33.7s	remaining: 9.22s
# 157:	learn: 0.3451503	total: 33.9s	remaining: 9s
# 158:	learn: 0.3451478	total: 34.1s	remaining: 8.78s
# 159:	learn: 0.3451463	total: 34.3s	remaining: 8.57s
# 160:	learn: 0.3451394	total: 34.5s	remaining: 8.36s
# 161:	learn: 0.3451344	total: 34.7s	remaining: 8.14s
# 162:	learn: 0.3451297	total: 34.9s	remaining: 7.92s
# 163:	learn: 0.3451197	total: 35.1s	remaining: 7.7s
# 164:	learn: 0.3451141	total: 35.3s	remaining: 7.49s
# 165:	learn: 0.3451082	total: 35.5s	remaining: 7.27s
# 166:	learn: 0.3451029	total: 35.7s	remaining: 7.05s
# 167:	learn: 0.3450978	total: 35.9s	remaining: 6.84s
# 168:	learn: 0.3450414	total: 36.1s	remaining: 6.63s
# 169:	learn: 0.3449855	total: 36.3s	remaining: 6.41s
# 170:	learn: 0.3449079	total: 36.5s	remaining: 6.19s
# 171:	learn: 0.3448795	total: 36.7s	remaining: 5.97s
# 172:	learn: 0.3448720	total: 36.9s	remaining: 5.76s
# 173:	learn: 0.3448622	total: 37.1s	remaining: 5.54s
# 174:	learn: 0.3448592	total: 37.3s	remaining: 5.33s
# 175:	learn: 0.3448518	total: 37.5s	remaining: 5.12s
# 176:	learn: 0.3448493	total: 37.7s	remaining: 4.9s
# 177:	learn: 0.3448440	total: 37.9s	remaining: 4.68s
# 178:	learn: 0.3448379	total: 38.1s	remaining: 4.47s
# 179:	learn: 0.3448248	total: 38.3s	remaining: 4.26s
# 180:	learn: 0.3448194	total: 38.5s	remaining: 4.04s
# 181:	learn: 0.3448149	total: 38.7s	remaining: 3.83s
# 182:	learn: 0.3448062	total: 38.9s	remaining: 3.61s
# 183:	learn: 0.3447890	total: 39.1s	remaining: 3.4s
# 184:	learn: 0.3447867	total: 39.3s	remaining: 3.19s
# 185:	learn: 0.3447773	total: 39.5s	remaining: 2.98s
# 186:	learn: 0.3447666	total: 39.7s	remaining: 2.76s
# 187:	learn: 0.3447609	total: 39.9s	remaining: 2.55s
# 188:	learn: 0.3447551	total: 40.1s	remaining: 2.33s
# 189:	learn: 0.3447497	total: 40.3s	remaining: 2.12s
# 190:	learn: 0.3447447	total: 40.5s	remaining: 1.91s
# 191:	learn: 0.3447274	total: 40.7s	remaining: 1.7s
# 192:	learn: 0.3447196	total: 40.9s	remaining: 1.48s
# 193:	learn: 0.3447148	total: 41.1s	remaining: 1.27s
# 194:	learn: 0.3447119	total: 41.3s	remaining: 1.06s
# 195:	learn: 0.3447040	total: 41.5s	remaining: 848ms
# 196:	learn: 0.3446990	total: 41.7s	remaining: 636ms
# 197:	learn: 0.3446985	total: 42s	remaining: 424ms
# 198:	learn: 0.3446930	total: 42.2s	remaining: 212ms
# 199:	learn: 0.3446866	total: 42.4s	remaining: 0us

# %%
catboost.feature_names_
# Out:
# ['hour',
#  'month',
#  'gender',
#  'age',
#  'country',
#  'city',
#  'exp_group',
#  'os',
#  'source',
#  'topic',
#  'TextCluster',
#  'DistanceToCluster_0',
#  'DistanceToCluster_1',
#  'DistanceToCluster_2',
#  'DistanceToCluster_3',
#  'DistanceToCluster_4',
#  'DistanceToCluster_5',
#  'DistanceToCluster_6',
#  'DistanceToCluster_7',
#  'DistanceToCluster_8',
#  'DistanceToCluster_9',
#  'DistanceToCluster_10',
#  'DistanceToCluster_11',
#  'DistanceToCluster_12',
#  'DistanceToCluster_13',
#  'DistanceToCluster_14',
#  'TotalTfIdf']

# %%
# model.save_model('test_catboost_model', format="cbm")
